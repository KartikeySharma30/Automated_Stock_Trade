# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.46-py2.py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pandas>=1.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from yfinance) (2.1.4)
# Requirement already satisfied: numpy>=1.16.5 in /opt/anaconda3/lib/python3.11/site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/lib/python3.11/site-packages (from yfinance) (2.31.0)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: lxml>=4.9.1 in /opt/anaconda3/lib/python3.11/site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in /opt/anaconda3/lib/python3.11/site-packages (from yfinance) (2023.3.post1)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.6-py311-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.17.7.tar.gz (939 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 939.5/939.5 kB 14.9 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/anaconda3/lib/python3.11/site-packages (from yfinance) (4.12.2)
# Collecting html5lib>=1.1 (from yfinance)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /opt/anaconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2024.2.2)
# Downloading yfinance-0.2.46-py2.py3-none-any.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.0/101.0 kB 14.6 MB/s eta 0:00:00
# Downloading frozendict-2.4.6-py311-none-any.whl (16 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 16.4 MB/s eta 0:00:00
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml) ... done
#   Created wheel for peewee: filename=peewee-3.17.7-cp311-cp311-macosx_11_0_arm64.whl size=263940 sha256=726fbff81dcff4e8222383c0fc4fe58eebb124eb043dc7e930bf82877fece131
#   Stored in directory: /Users/kartikeysharma/Library/Caches/pip/wheels/fd/28/34/9ba1363b76703fe35ae8296af28ea74578a41b83544bb9da65
# Successfully built peewee
# Installing collected packages: peewee, multitasking, html5lib, frozendict, yfinance
# Successfully installed frozendict-2.4.6 html5lib-1.1 multitasking-0.0.11 peewee-3.17.7 yfinance-0.2.46

# %%
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta

def fetch_intraday_data(symbol='^NSEI', interval='5m', target_points=10000):
    all_data = []  # Store fetched data in chunks
    end_date = datetime.today()  # Initialize end date
    batch_size = 60  # Yahoo Finance allows 60-day intraday data per request

    total_points = 0  # Track the total number of data points collected

    while total_points < target_points:
        start_date = end_date - timedelta(days=batch_size)  # 60-day range
        print(f"Fetching data from {start_date.date()} to {end_date.date()}...")

        try:
            # Fetch intraday data from Yahoo Finance
            df = yf.download(
                symbol, start=start_date, end=end_date, interval=interval, progress=False
            )

            if df.empty:
                print(f"No data found for {start_date.date()} to {end_date.date()}.")
                break

            all_data.append(df)  # Add the fetched data to the list
            total_points += len(df)  # Update the total points collected
            print(f"Collected {len(df)} points. Total so far: {total_points} points.")

        except Exception as e:
            print(f"Error fetching data: {e}")
            break

        # Move the end date to the start of the current range for the next batch
        end_date = start_date

    # Combine all data into a single DataFrame
    if all_data:
        result = pd.concat(all_data).sort_index()
        print(f"Total data points collected: {len(result)}")
        return result
    else:
        print("No data fetched.")
        return pd.DataFrame()

# Example usage
data = fetch_intraday_data(symbol='^BSESN', interval='1d', target_points=15000)

# Display the first few rows
print(data.head())

# Save to CSV if data was collected successfully
if not data.empty:
   data.to_csv('BSE_SENSEX_data.csv')
   #print("Data saved to 'Nifty50_intraday_data.csv'")
# Out:
# Fetching data from 2024-08-29 to 2024-10-28...
# Collected 42 points. Total so far: 42 points.
# Fetching data from 2024-06-30 to 2024-08-29...
# Collected 42 points. Total so far: 84 points.
# Fetching data from 2024-05-01 to 2024-06-30...
# Collected 40 points. Total so far: 124 points.
# Fetching data from 2024-03-02 to 2024-05-01...
# Collected 37 points. Total so far: 161 points.
# Fetching data from 2024-01-02 to 2024-03-02...
# Collected 42 points. Total so far: 203 points.
# Fetching data from 2023-11-03 to 2024-01-02...
# Collected 39 points. Total so far: 242 points.
# Fetching data from 2023-09-04 to 2023-11-03...
# Collected 42 points. Total so far: 284 points.
# Fetching data from 2023-07-06 to 2023-09-04...
# Collected 42 points. Total so far: 326 points.
# Fetching data from 2023-05-07 to 2023-07-06...
# Collected 43 points. Total so far: 369 points.
# Fetching data from 2023-03-08 to 2023-05-07...
# Collected 38 points. Total so far: 407 points.
# Fetching data from 2023-01-07 to 2023-03-08...
# Collected 41 points. Total so far: 448 points.
# Fetching data from 2022-11-08 to 2023-01-07...
# Collected 43 points. Total so far: 491 points.
# Fetching data from 2022-09-09 to 2022-11-08...
# Collected 40 points. Total so far: 531 points.
# Fetching data from 2022-07-11 to 2022-09-09...
# Collected 42 points. Total so far: 573 points.
# Fetching data from 2022-05-12 to 2022-07-11...
# Collected 43 points. Total so far: 616 points.
# Fetching data from 2022-03-13 to 2022-05-12...
# Collected 40 points. Total so far: 656 points.
# Fetching data from 2022-01-12 to 2022-03-13...
# Collected 41 points. Total so far: 697 points.
# Fetching data from 2021-11-13 to 2022-01-12...
# Collected 42 points. Total so far: 739 points.
# Fetching data from 2021-09-14 to 2021-11-13...
# Collected 42 points. Total so far: 781 points.
# Fetching data from 2021-07-16 to 2021-09-14...
# Collected 40 points. Total so far: 821 points.
# Fetching data from 2021-05-17 to 2021-07-16...
# Collected 45 points. Total so far: 866 points.
# Fetching data from 2021-03-18 to 2021-05-17...
# Collected 37 points. Total so far: 903 points.
# Fetching data from 2021-01-17 to 2021-03-18...
# Collected 42 points. Total so far: 945 points.
# Fetching data from 2020-11-18 to 2021-01-17...
# Collected 41 points. Total so far: 986 points.
# Fetching data from 2020-09-19 to 2020-11-18...
# Collected 41 points. Total so far: 1027 points.
# Fetching data from 2020-07-21 to 2020-09-19...
# Collected 44 points. Total so far: 1071 points.
# Fetching data from 2020-05-22 to 2020-07-21...
# Collected 42 points. Total so far: 1113 points.
# Fetching data from 2020-03-23 to 2020-05-22...
# Collected 40 points. Total so far: 1153 points.
# Fetching data from 2020-01-23 to 2020-03-23...
# Collected 41 points. Total so far: 1194 points.
# Fetching data from 2019-11-24 to 2020-01-23...
# Collected 42 points. Total so far: 1236 points.
# Fetching data from 2019-09-25 to 2019-11-24...
# Collected 38 points. Total so far: 1274 points.
# Fetching data from 2019-07-27 to 2019-09-25...
# Collected 39 points. Total so far: 1313 points.
# Fetching data from 2019-05-28 to 2019-07-27...
# Collected 43 points. Total so far: 1356 points.
# Fetching data from 2019-03-29 to 2019-05-28...
# Collected 38 points. Total so far: 1394 points.
# Fetching data from 2019-01-28 to 2019-03-29...
# Collected 41 points. Total so far: 1435 points.
# Fetching data from 2018-11-29 to 2019-01-28...
# Collected 41 points. Total so far: 1476 points.
# Fetching data from 2018-09-30 to 2018-11-29...
# Collected 40 points. Total so far: 1516 points.
# Fetching data from 2018-08-01 to 2018-09-30...
# Collected 39 points. Total so far: 1555 points.
# Fetching data from 2018-06-02 to 2018-08-01...
# Collected 43 points. Total so far: 1598 points.
# Fetching data from 2018-04-03 to 2018-06-02...
# Collected 43 points. Total so far: 1641 points.
# Fetching data from 2018-02-02 to 2018-04-03...
# Collected 39 points. Total so far: 1680 points.
# Fetching data from 2017-12-04 to 2018-02-02...
# Collected 43 points. Total so far: 1723 points.
# Fetching data from 2017-10-05 to 2017-12-04...
# Collected 42 points. Total so far: 1765 points.
# Fetching data from 2017-08-06 to 2017-10-05...
# Collected 41 points. Total so far: 1806 points.
# Fetching data from 2017-06-07 to 2017-08-06...
# Collected 42 points. Total so far: 1848 points.
# Fetching data from 2017-04-08 to 2017-06-07...
# Collected 41 points. Total so far: 1889 points.
# Fetching data from 2017-02-07 to 2017-04-08...
# Collected 41 points. Total so far: 1930 points.
# Fetching data from 2016-12-09 to 2017-02-07...
# Collected 42 points. Total so far: 1972 points.
# Fetching data from 2016-10-10 to 2016-12-09...
# Collected 41 points. Total so far: 2013 points.
# Fetching data from 2016-08-11 to 2016-10-10...
# Collected 40 points. Total so far: 2053 points.
# Fetching data from 2016-06-12 to 2016-08-11...
# Collected 43 points. Total so far: 2096 points.
# Fetching data from 2016-04-13 to 2016-06-12...
# Collected 40 points. Total so far: 2136 points.
# Fetching data from 2016-02-13 to 2016-04-13...
# Collected 40 points. Total so far: 2176 points.
# Fetching data from 2015-12-15 to 2016-02-13...
# Collected 41 points. Total so far: 2217 points.
# Fetching data from 2015-10-16 to 2015-12-15...
# Collected 39 points. Total so far: 2256 points.
# Fetching data from 2015-08-17 to 2015-10-16...
# Collected 42 points. Total so far: 2298 points.
# Fetching data from 2015-06-18 to 2015-08-17...
# Collected 43 points. Total so far: 2341 points.
# Fetching data from 2015-04-19 to 2015-06-18...
# Collected 43 points. Total so far: 2384 points.
# Fetching data from 2015-02-18 to 2015-04-19...
# Collected 39 points. Total so far: 2423 points.
# Fetching data from 2014-12-20 to 2015-02-18...
# Collected 37 points. Total so far: 2460 points.
# Fetching data from 2014-10-21 to 2014-12-20...
# Collected 40 points. Total so far: 2500 points.
# Fetching data from 2014-08-22 to 2014-10-21...
# Collected 38 points. Total so far: 2538 points.
# Fetching data from 2014-06-23 to 2014-08-22...
# Collected 43 points. Total so far: 2581 points.
# Fetching data from 2014-04-24 to 2014-06-23...
# Collected 41 points. Total so far: 2622 points.
# Fetching data from 2014-02-23 to 2014-04-24...
# Collected 38 points. Total so far: 2660 points.
# Fetching data from 2013-12-25 to 2014-02-23...
# Collected 42 points. Total so far: 2702 points.
# Fetching data from 2013-10-26 to 2013-12-25...
# Collected 40 points. Total so far: 2742 points.
# Fetching data from 2013-08-27 to 2013-10-26...
# Collected 41 points. Total so far: 2783 points.
# Fetching data from 2013-06-28 to 2013-08-27...
# Collected 41 points. Total so far: 2824 points.
# Fetching data from 2013-04-29 to 2013-06-28...
# Collected 44 points. Total so far: 2868 points.
# Fetching data from 2013-02-28 to 2013-04-29...
# Collected 39 points. Total so far: 2907 points.
# Fetching data from 2012-12-30 to 2013-02-28...
# Collected 43 points. Total so far: 2950 points.
# Fetching data from 2012-10-31 to 2012-12-30...
# Collected 39 points. Total so far: 2989 points.
# Fetching data from 2012-09-01 to 2012-10-31...
# Collected 39 points. Total so far: 3028 points.
# Fetching data from 2012-07-03 to 2012-09-01...
# Collected 42 points. Total so far: 3070 points.
# Fetching data from 2012-05-04 to 2012-07-03...
# Collected 43 points. Total so far: 3113 points.
# Fetching data from 2012-03-05 to 2012-05-04...
# Collected 41 points. Total so far: 3154 points.
# Fetching data from 2012-01-05 to 2012-03-05...
# Collected 41 points. Total so far: 3195 points.
# Fetching data from 2011-11-06 to 2012-01-05...
# Collected 40 points. Total so far: 3235 points.
# Fetching data from 2011-09-07 to 2011-11-06...
# Collected 40 points. Total so far: 3275 points.
# Fetching data from 2011-07-09 to 2011-09-07...
# Collected 40 points. Total so far: 3315 points.
# Fetching data from 2011-05-10 to 2011-07-09...
# Collected 44 points. Total so far: 3359 points.
# Fetching data from 2011-03-11 to 2011-05-10...
# Collected 40 points. Total so far: 3399 points.
# Fetching data from 2011-01-10 to 2011-03-11...
# Collected 43 points. Total so far: 3442 points.
# Fetching data from 2010-11-11 to 2011-01-10...
# Collected 41 points. Total so far: 3483 points.
# Fetching data from 2010-09-12 to 2010-11-11...
# Collected 43 points. Total so far: 3526 points.
# Fetching data from 2010-07-14 to 2010-09-12...
# Collected 42 points. Total so far: 3568 points.
# Fetching data from 2010-05-15 to 2010-07-14...
# Collected 43 points. Total so far: 3611 points.
# Fetching data from 2010-03-16 to 2010-05-15...
# Collected 41 points. Total so far: 3652 points.
# Fetching data from 2010-01-15 to 2010-03-16...
# Collected 40 points. Total so far: 3692 points.
# Fetching data from 2009-11-16 to 2010-01-15...
# Collected 42 points. Total so far: 3734 points.
# Fetching data from 2009-09-17 to 2009-11-16...
# Collected 37 points. Total so far: 3771 points.
# Fetching data from 2009-07-19 to 2009-09-17...
# Collected 44 points. Total so far: 3815 points.
# Fetching data from 2009-05-20 to 2009-07-19...
# Collected 43 points. Total so far: 3858 points.
# Fetching data from 2009-03-21 to 2009-05-20...
# Collected 37 points. Total so far: 3895 points.
# Fetching data from 2009-01-20 to 2009-03-21...
# Collected 40 points. Total so far: 3935 points.
# Fetching data from 2008-11-21 to 2009-01-20...
# Collected 38 points. Total so far: 3973 points.
# Fetching data from 2008-09-22 to 2008-11-21...
# Collected 40 points. Total so far: 4013 points.
# Fetching data from 2008-07-24 to 2008-09-22...
# Collected 41 points. Total so far: 4054 points.
# Fetching data from 2008-05-25 to 2008-07-24...
# Collected 44 points. Total so far: 4098 points.
# Fetching data from 2008-03-26 to 2008-05-25...
# Collected 39 points. Total so far: 4137 points.
# Fetching data from 2008-01-26 to 2008-03-26...
# Collected 40 points. Total so far: 4177 points.
# Fetching data from 2007-11-27 to 2008-01-26...
# Collected 41 points. Total so far: 4218 points.
# Fetching data from 2007-09-28 to 2007-11-27...
# Collected 41 points. Total so far: 4259 points.
# Fetching data from 2007-07-30 to 2007-09-28...
# Collected 44 points. Total so far: 4303 points.
# Fetching data from 2007-05-31 to 2007-07-30...
# Collected 43 points. Total so far: 4346 points.
# Fetching data from 2007-04-01 to 2007-05-31...
# Collected 41 points. Total so far: 4387 points.
# Fetching data from 2007-01-31 to 2007-04-01...
# Collected 41 points. Total so far: 4428 points.
# Fetching data from 2006-12-02 to 2007-01-31...
# Collected 39 points. Total so far: 4467 points.
# Fetching data from 2006-10-03 to 2006-12-02...
# Collected 42 points. Total so far: 4509 points.
# Fetching data from 2006-08-04 to 2006-10-03...
# Collected 41 points. Total so far: 4550 points.
# Fetching data from 2006-06-05 to 2006-08-04...
# Collected 45 points. Total so far: 4595 points.
# Fetching data from 2006-04-06 to 2006-06-05...
# Collected 39 points. Total so far: 4634 points.
# Fetching data from 2006-02-05 to 2006-04-06...
# Collected 41 points. Total so far: 4675 points.
# Fetching data from 2005-12-07 to 2006-02-05...
# Collected 41 points. Total so far: 4716 points.
# Fetching data from 2005-10-08 to 2005-12-07...
# Collected 38 points. Total so far: 4754 points.
# Fetching data from 2005-08-09 to 2005-10-08...
# Collected 42 points. Total so far: 4796 points.
# Fetching data from 2005-06-10 to 2005-08-09...
# Collected 42 points. Total so far: 4838 points.
# Fetching data from 2005-04-11 to 2005-06-10...
# Collected 44 points. Total so far: 4882 points.
# Fetching data from 2005-02-10 to 2005-04-11...
# Collected 42 points. Total so far: 4924 points.
# Fetching data from 2004-12-12 to 2005-02-10...
# Collected 42 points. Total so far: 4966 points.
# Fetching data from 2004-10-13 to 2004-12-12...
# Collected 39 points. Total so far: 5005 points.
# Fetching data from 2004-08-14 to 2004-10-13...
# Collected 42 points. Total so far: 5047 points.
# Fetching data from 2004-06-15 to 2004-08-14...
# Collected 44 points. Total so far: 5091 points.
# Fetching data from 2004-04-16 to 2004-06-15...
# Collected 42 points. Total so far: 5133 points.
# Fetching data from 2004-02-16 to 2004-04-16...
# Collected 42 points. Total so far: 5175 points.
# Fetching data from 2003-12-18 to 2004-02-16...
# Collected 39 points. Total so far: 5214 points.
# Fetching data from 2003-10-19 to 2003-12-18...
# Collected 43 points. Total so far: 5257 points.
# Fetching data from 2003-08-20 to 2003-10-19...
# Collected 42 points. Total so far: 5299 points.
# Fetching data from 2003-06-21 to 2003-08-20...
# Collected 42 points. Total so far: 5341 points.
# Fetching data from 2003-04-22 to 2003-06-21...
# Collected 43 points. Total so far: 5384 points.
# Fetching data from 2003-02-21 to 2003-04-22...
# Collected 39 points. Total so far: 5423 points.
# Fetching data from 2002-12-23 to 2003-02-21...
# Collected 42 points. Total so far: 5465 points.
# Fetching data from 2002-10-24 to 2002-12-23...
# Collected 41 points. Total so far: 5506 points.
# Fetching data from 2002-08-25 to 2002-10-24...
# Collected 41 points. Total so far: 5547 points.
# Fetching data from 2002-06-26 to 2002-08-25...
# Collected 42 points. Total so far: 5589 points.
# Fetching data from 2002-04-27 to 2002-06-26...
# Collected 42 points. Total so far: 5631 points.
# Fetching data from 2002-02-26 to 2002-04-27...
# Collected 42 points. Total so far: 5673 points.
# Fetching data from 2001-12-28 to 2002-02-26...
# Collected 42 points. Total so far: 5715 points.
# Fetching data from 2001-10-29 to 2001-12-28...
# Collected 41 points. Total so far: 5756 points.
# Fetching data from 2001-08-30 to 2001-10-29...
# Collected 41 points. Total so far: 5797 points.
# Fetching data from 2001-07-01 to 2001-08-30...
# Collected 42 points. Total so far: 5839 points.
# Fetching data from 2001-05-02 to 2001-07-01...
# Collected 43 points. Total so far: 5882 points.
# Fetching data from 2001-03-03 to 2001-05-02...
# Collected 39 points. Total so far: 5921 points.
# Fetching data from 2001-01-02 to 2001-03-03...
# Collected 43 points. Total so far: 5964 points.
# Fetching data from 2000-11-03 to 2001-01-02...
# Collected 41 points. Total so far: 6005 points.
# Fetching data from 2000-09-04 to 2000-11-03...
# Collected 43 points. Total so far: 6048 points.
# Fetching data from 2000-07-06 to 2000-09-04...
# Collected 41 points. Total so far: 6089 points.
# Fetching data from 2000-05-07 to 2000-07-06...
# Collected 44 points. Total so far: 6133 points.
# Fetching data from 2000-03-08 to 2000-05-07...
# Collected 38 points. Total so far: 6171 points.
# Fetching data from 2000-01-08 to 2000-03-08...
# Collected 43 points. Total so far: 6214 points.
# Fetching data from 1999-11-09 to 2000-01-08...
# Collected 41 points. Total so far: 6255 points.
# Fetching data from 1999-09-10 to 1999-11-09...
# Collected 40 points. Total so far: 6295 points.
# Fetching data from 1999-07-12 to 1999-09-10...
# Collected 45 points. Total so far: 6340 points.
# Fetching data from 1999-05-13 to 1999-07-12...
# Collected 43 points. Total so far: 6383 points.
# Fetching data from 1999-03-14 to 1999-05-13...
# Collected 38 points. Total so far: 6421 points.
# Fetching data from 1999-01-13 to 1999-03-14...
# Collected 40 points. Total so far: 6461 points.
# Fetching data from 1998-11-14 to 1999-01-13...
# Collected 41 points. Total so far: 6502 points.
# Fetching data from 1998-09-15 to 1998-11-14...
# Collected 39 points. Total so far: 6541 points.
# Fetching data from 1998-07-17 to 1998-09-15...
# Collected 42 points. Total so far: 6583 points.
# Fetching data from 1998-05-18 to 1998-07-17...
# Collected 45 points. Total so far: 6628 points.
# Fetching data from 1998-03-19 to 1998-05-18...
# Collected 37 points. Total so far: 6665 points.
# Fetching data from 1998-01-18 to 1998-03-19...
# Collected 39 points. Total so far: 6704 points.
# Fetching data from 1997-11-19 to 1998-01-18...
# Collected 42 points. Total so far: 6746 points.
# Fetching data from 1997-09-20 to 1997-11-19...
# Collected 39 points. Total so far: 6785 points.
# Fetching data from 1997-07-22 to 1997-09-20...
# Collected 41 points. Total so far: 6826 points.
# Fetching data from 1997-05-23 to 1997-07-22...
# Collected 16 points. Total so far: 6842 points.
# Fetching data from 1997-03-24 to 1997-05-23...
# 1 Failed download:
# ['^BSESN']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 1997-03-24 21:14:32.284158 -> 1997-05-23 21:14:32.284158) (Yahoo error = "Data doesn\'t exist for startDate = 859218272, endDate = 864402272")')
# No data found for 1997-03-24 to 1997-05-23.
# Total data points collected: 6842
# Price                        Adj Close        Close         High          Low  \
# Ticker                          ^BSESN       ^BSESN       ^BSESN       ^BSESN
# Date
# 1997-07-01 00:00:00+00:00  4300.859863  4300.859863  4301.770020  4247.660156
# 1997-07-02 00:00:00+00:00  4333.899902  4333.899902  4395.310059  4295.399902
# 1997-07-03 00:00:00+00:00  4323.459961  4323.459961  4393.290039  4299.970215
# 1997-07-04 00:00:00+00:00  4323.819824  4323.819824  4347.589844  4300.580078
# 1997-07-07 00:00:00+00:00  4291.450195  4291.450195  4391.009766  4289.490234
#
# Price                             Open Volume
# Ticker                          ^BSESN ^BSESN
# Date
# 1997-07-01 00:00:00+00:00  4263.109863      0
# 1997-07-02 00:00:00+00:00  4302.959961      0
# 1997-07-03 00:00:00+00:00  4335.790039      0
# 1997-07-04 00:00:00+00:00  4332.700195      0
# 1997-07-07 00:00:00+00:00  4326.810059      0
